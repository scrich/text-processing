# %% [markdown]
# # Open files in folder, process, save output files

# %% [markdown]
# ## Initialisation
# Load required modules

# %%
# initialisation

import pandas as pd
pd.__version__
# Out:
# '0.24.2'

# %%
import re
re.__version__
# Out:
# '2.2.1'

# %%
import csv
csv.__version__
# Out:
# '1.0'

# %%
import os

# %% [markdown]
# ## Define functions

# %%
# filename = 'news20190320_out'
#filename = 'news_bodytext_20191002_prep_out'
filename = 'news_unclassified_prep_out'


##
# get the csv into pandas
    
df = pd.DataFrame
df = pd.read_csv('./'+filename+'.csv')

# %%
df['Body_len'] = df['Body'].str.split(" ").apply(len)

# %%
df.to_csv('./'+filename+'_count.csv', index=False, quoting=csv.QUOTE_NONNUMERIC)

# %%
df
# Out:
#                                                    Body       Category  \
# 0     plans for creating new junior age school place...  uncategorised
# 1     changes to make brighton and hove city council...  uncategorised
# 2     roger french, obe, will become an honorary fre...  uncategorised
# 3     schools across brighton and hove will be takin...  uncategorised
# 4     brighton and hove city council is planning to ...  uncategorised
# 5     school admissions arrangements for brighton an...  uncategorised
# 6     homes plan will preserve historic kemp town vi...  uncategorised
# 7     residents have their pick of arts events this ...  uncategorised
# 8     brighton and hove becomes the world&rsquo;s fi...  uncategorised
# 9     england rugby  (er ), tournament organisers, a...  uncategorised
# 10    b.fest &ndash; brighton youth arts festival is...  uncategorised
# 11    an innovative project to encourage designers t...  uncategorised
# ...
